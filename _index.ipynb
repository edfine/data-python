# %% [markdown]
# # Data Focused Python
#
# Ed Fine<br/>
# edward.fine@afinepoint.net<br/>
#
# ## Schedule
#
# Class times: 09:00a - 5:00p (Pacific)
#
# Lunch: 12:00 - 1:00
#
# In addition to labs, breaks every ~50-70min
#
# ## Courseware
#
# https://github.com/edfine/data-python

# %% [markdown]
# # While we are waiting to start
#
# We use Jupyter notebook ([html][jupyter-html] or [ipynb][jupyter-nb]) for the courseware, so ensuring you can run it will allow you to follow along.
#
# If you use Pip, you can use the pip setup instructions ([html][setup-pip-html] or [ipynb][setup-pip-nb]).
#
# If you use Anaconda (or wish to), you can use the Anaconda setup instructions ([html][setup-anaconda-html] or [ipynb][setup-anaconda-nb])
#
# [jupyter-html]: ./jupyter.html
# [jupyter-nb]: ./jupyter.ipynb
# [setup-pip-html]: ./Setup-Pip.html
# [setup-pip-nb]: ./Setup-Pip.ipynb
# [setup-anaconda-html]: ./Setup-Anaconda.html
# [setup-anaconda-nb]: ./Setup-Anaconda.ipynb

# %% [markdown]
# # Course Outline and Schedule
#
# ## Day 1
#
# - Intro
#   - [Jupyter, briefly][jupyter]
#   - [Core Python Review][fast-intro-python]
#
# - Advanced Python Syntax
#     - [Iteratables, Iterators, and Generators][iteration]
#     - [Closures and Decorators][closures]
#
# - OOP
#   - [OOP Review][oop-intro]
#   - [OOP Magic][oop-magic]
#   - OOP Inheritance
#
# - Numerical Python
#     -[Numpy][numpy]
#
# - Pandas
#   - [Intro, importing and exporting data][pandas-io]
#   - [Filtering and exploring data][pandas-exploration]
#   - [Merging and Concatenation][pandas-merging]
#   - [Data Aggregation][pandas-aggregation]
#   - [Basic Visualization][pandas-plotting]
#
#
# ## Day 2
#
# - Pandas, Continued
#   - [Intro, importing and exporting data][pandas-io]
#   - [Filtering and exploring data][pandas-exploration]
#   - [Merging and Concatenation][pandas-merging]
#   - [Data Aggregation][pandas-aggregation]
#   - [Basic Visualization][pandas-plotting]
#   - [Extensions to Pandas][pandas-extensions]
#
# - Advanced OOP
#     - [Closures and Decorators][closures]
#     - [Descriptors][descriptors]
#     - [Class Decorators][class-decorators]
#
# - Database Programming
#     - [Integrating with relational databases][dbapi]
#     - [Integrating with MongoDB][pymongo]
#
# - More Advanced Python Syntax
#     - [Advanced Generators: Pipelines and Coroutines][advanced-generators]
#     - [Asynchronous IO][asyncio]
#
# ## Day 3
# - Visualisation
#     - Seaborn
#     - Altair and the Grammar of Graphics
#
# - Pydantic data modelling
#
#   ## Day 4
#
# - [Virtual Environments][virtualenv]
# - [Packaging Projects for Distribution][packaging]
#
# - The Import-Export Business
#     -[Json]
#     -[xml]
#     -[Arrow]
#     -[Parquet]
#
# - Network Programming
#     - [Consuming APIs Using Requests][requests]
#     - [Producing modern APIs with FastAPI]
#     - [Serving Analytics]
#
#
#
# ## Additional Topics (as time permits or needed)
#
# - [Advanced Data Types][advanced-data-types]
# - [Functional Programming][functional]
# - [Closures and Decorators][closures]
# - [NumPy][numpy]
# - [Testing in Python][testing]
#   - [Mocking / DI][mock]
# - Optional static type annotations
#   - [Mypy][mypy]
#   - [Dataclasses][dataclasses]
#
#
# [jupyter]: ./jupyter.ipynb
# [fast-intro-python]: ./fast-intro-python.ipynb
# [iteration]: ./iteration.ipynb
# [advanced-generators]: ./advanced-generators.ipynb
# [asyncio]: ./asyncio.ipynb
# [descriptors]: ./descriptors.ipynb
# [class-decorators]: ./class-decorators.ipynb
# [metaclasses]: ./metaclasses.ipynb
# [advanced-oop]: ./advanced-oop.ipynb
# [virtualenv]: ./virtualenv.ipynb
# [packaging]: ./packaging.ipynb
# [requests]: ./requests.ipynb
# [wsgi]: ./wsgi.ipynb
# [sgml]: ./sgml.ipynb
# [dbapi]: ./dbapi.ipynb
# [pymongo]: ./pymongo.ipynb
# [mypy]: ./mypy.ipynb
# [dataclasses]: ./dataclasses.ipynb
# [oop-intro]: ./oop-intro.ipynb
# [oop-magic]: ./oop-magic.ipynb
#
# [closures]: ./closures.ipynb
# [numpy]: ./numpy.ipynb
# [pandas]: ./pandas.ipynb
# [pandas-io]: ./pandas-io.ipynb
# [pandas-exploration]: ./pandas-exploration.ipynb
# [pandas-merging]: ./pandas-merging.ipynb
# [pandas-aggregation]: ./pandas-aggregation.ipynb
# [pandas-plotting]: ./pandas-plotting.ipynb
